# %%
import pickle 
import pandas as pd

# %%
##loaded the dynamic file and load the bulk of file data assign the value into load_model
load_model = pickle.load(open("master_preprocess_input_output.sav", 'rb'))
scx= pickle.load(open("inputscaler_preprocess.sav", 'rb'))
scy= pickle.load(open("outputscaler_preprocess.sav", 'rb'))

# load_model.predict pass the numbers of input it will exexute we can able seethe in the result
##result = load_model.predict([[23640.93,96189.63,148001.11,0,1]])

# %%
preinput=scx.transform([[1300,34000,1000,1,0]])
# Out:
# C:\Users\bkmad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-1.46755405, -3.48433536, -1.53042948,  2.        , -0.76870611]])

# %%
result = load_model.predict(preinput)

# %%
result
# Out:
# array([-1.46574651])

# %%
preoutput=scy.inverse_transform([result])

# %%
preoutput
# Out:
# array([[47179.51485392]])
