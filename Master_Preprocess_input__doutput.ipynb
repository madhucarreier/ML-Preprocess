# %%
import pandas as pd
dataset=pd.read_csv("50_Startups.csv")
dataset=pd.get_dummies(dataset,drop_first=True)
independent=dataset[['R&D Spend', 'Administration', 'Marketing Spend','State_Florida', 'State_New York']]
dependent=dataset[["Profit"]]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)

# %%
X_test.shape
y_train.shape #row and column count
# Out:
# (35, 1)

# %%
from sklearn.preprocessing import StandardScaler
scx=StandardScaler()
X_train=scx.fit_transform(X_train)
X_test=scx.transform(X_test)

# %%
scy=StandardScaler()
y_train=scy.fit_transform(y_train)
y_test=scy.transform(y_test)

# %%
from sklearn.svm import SVR  #These first two lines are called as a procedure
regressorx=SVR(kernel="linear") #Data behaviour - Pattern - Linear Pattern
regressorx.fit(X_train,y_train)#Fit - Called Function. X-input, Y-output
# Out:
# C:\Users\bkmad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='linear')

# %%
y_pred=regressorx.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.9376541575420615

# %%
preinput=scx.transform([[1300,12000,4000,0,1]])
# Out:
# C:\Users\bkmad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-1.46755405, -4.33835385, -1.50744257, -0.5       ,  1.30088727]])

# %%
#import pickle
#filename="Preprocess_input_output.sav" #File name must be in .sav in the last
#pickle.dump(regressor,open(filename,'wb'))
#pickle.dump(sc, open("scaler.sav","wb"))

import pickle
filename="master_preprocess_input_output.sav"
filename1="inputscaler_preprocess.sav"
filename2="outputscaler_preprocess.sav"

# %%
pickle.dump(regressorx,open(filename,'wb'))
pickle.dump(scx,open(filename1,'wb'))
pickle.dump(scy,open(filename2,'wb'))

# %%
 #How to save model
import pickle
loaded_model=pickle.load(open("master_preprocess_input_output.sav",'rb')) #Checking a saved model, whether working properly 
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([-1.49057693])

# %%
#loaded_model=pickle.load(open("finalized_model_svm_regression.sav",'rb')) #Checking a saved model, whether working properly 
#result=loaded_model.predict(preinput)

# %%
pryoutput=scy.inverse_transform([result])

# %%
pryoutput
# Out:
# array([[46111.49013717]])
